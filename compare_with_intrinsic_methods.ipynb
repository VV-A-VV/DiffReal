# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('test_outputs/albedo_pred_alb.png')
albedo = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# albedo1 = cv2.cvtColor(albedo, cv2.COLOR_RGB2BGR)
albedo = albedo / 255.0
plt.imshow(albedo)

# %%
for i in range(6,12):
    # generated_shadow = cv2.imread('test_outputs/generated/' + str(i) + '_pred_shd.png')
    generated_albedo = cv2.imread('test_outputs/generated/' + str(i) + '_pred_alb.png')
    # generated_shadow = cv2.cvtColor(generated_shadow, cv2.COLOR_BGR2RGB)
    generated_albedo = cv2.cvtColor(generated_albedo, cv2.COLOR_BGR2RGB)
    # rendered_shadow = cv2.imread('test_outputs/rendered/' + str(i) + '_pred_shd.png')
    rendered_albedo = cv2.imread('test_outputs/rendered/' + str(i) + '_pred_alb.png')
    # rendered_shadow = cv2.cvtColor(rendered_shadow, cv2.COLOR_BGR2RGB)
    rendered_albedo = cv2.cvtColor(rendered_albedo, cv2.COLOR_BGR2RGB)
    albedo = cv2.imread('test_outputs/albedo_pred_alb.png')
    albedo = cv2.cvtColor(albedo, cv2.COLOR_BGR2RGB)
    # albedo = albedo / 255.0
    # generated_shadow = generated_shadow / 255.0
    # generated_albedo = generated_albedo / 255.0
    # rendered_shadow = rendered_shadow / 255.0
    # rendered_albedo = rendered_albedo / 255.0
    #rendered shadow * generated albedo
    #generated shadow * rendered albedo
    #rendered shadow * albedo
    #generated shadow * albedo
    # rsga = np.multiply(rendered_shadow, generated_albedo)
    # gsra = np.multiply(generated_shadow, rendered_albedo)
    # rsa = np.multiply(rendered_shadow, albedo)
    # gsa = np.multiply(generated_shadow, albedo)
    # # save in the RGB format
    # # rsga = cv2.cvtColor(rsga, cv2.COLOR_RGB2BGR)
    # # gsra = cv2.cvtColor(gsra, cv2.COLOR_RGB2BGR)
    # # rsa = cv2.cvtColor(rsa, cv2.COLOR_RGB2BGR)
    # #scale back to 0-255
    # rsga = rsga * 255
    # gsra = gsra * 255
    # rsa = rsa * 255
    # gsa = gsa * 255

    # cv2.imwrite('test_outputs/compare/' + str(i) + '_rsga.png', rsga)
    # cv2.imwrite('test_outputs/compare/' + str(i) + '_gsra.png', gsra)
    # cv2.imwrite('test_outputs/compare/' + str(i) + '_rsa.png', rsa)
    # cv2.imwrite('test_outputs/compare/' + str(i) + '_gsa.png', gsa)
    # save the images
    cv2.imwrite('test_outputs/compare/' + str(i) + '_albedo.png', albedo)
    cv2.imwrite('test_outputs/compare/' + str(i) + '_generated_albedo.png', generated_albedo)
    cv2.imwrite('test_outputs/compare/' + str(i) + '_rendered_albedo.png', rendered_albedo)

# %%
for i in range(6,12):
    generated_shadow = cv2.imread('test_outputs/generated/' + str(i) + '_pred_shd.png')
    generated_albedo = cv2.imread('test_outputs/generated/' + str(i) + '_pred_alb.png')
    generated_shadow = cv2.cvtColor(generated_shadow, cv2.COLOR_BGR2RGB)
    generated_albedo = cv2.cvtColor(generated_albedo, cv2.COLOR_BGR2RGB)
    rendered_shadow = cv2.imread('test_outputs/rendered/' + str(i) + '_pred_shd.png')
    rendered_albedo = cv2.imread('test_outputs/rendered/' + str(i) + '_pred_alb.png')
    rendered_shadow = cv2.cvtColor(rendered_shadow, cv2.COLOR_BGR2RGB)
    rendered_albedo = cv2.cvtColor(rendered_albedo, cv2.COLOR_BGR2RGB)
    albedo = cv2.imread('test_outputs/albedo_pred_alb.png')
    albedo = cv2.cvtColor(albedo, cv2.COLOR_BGR2RGB)
    albedo = albedo / 255.0
    generated_shadow = generated_shadow / 255.0
    generated_albedo = generated_albedo / 255.0
    rendered_shadow = rendered_shadow / 255.0
    rendered_albedo = rendered_albedo / 255.0
    #rendered shadow * generated albedo
    #generated shadow * rendered albedo
    #rendered shadow * albedo
    #generated shadow * albedo
    rsga = np.multiply(rendered_shadow, generated_albedo)
    gsra = np.multiply(generated_shadow, rendered_albedo)
    rsa = np.multiply(rendered_shadow, albedo)
    gsa = np.multiply(generated_shadow, albedo)
    # save in the RGB format
    # rsga = cv2.cvtColor(rsga, cv2.COLOR_RGB2BGR)
    # gsra = cv2.cvtColor(gsra, cv2.COLOR_RGB2BGR)
    # rsa = cv2.cvtColor(rsa, cv2.COLOR_RGB2BGR)
    #scale back to 0-255
    rsga = rsga * 255
    gsra = gsra * 255
    rsa = rsa * 255
    gsa = gsa * 255

    cv2.imwrite('test_outputs/compare/' + str(i) + '_rsga.png', rsga)
    cv2.imwrite('test_outputs/compare/' + str(i) + '_gsra.png', gsra)
    cv2.imwrite('test_outputs/compare/' + str(i) + '_rsa.png', rsa)
    cv2.imwrite('test_outputs/compare/' + str(i) + '_gsa.png', gsa)
